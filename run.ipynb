# %%
import torch
import torch.nn as nn
from torchvision.transforms import transforms
import numpy as np
from torch.autograd import Variable
from torchvision.models import squeezenet1_1
import torch.functional as F
from io import open
import os
from PIL import Image
import pathlib
import glob
import cv2
from PIL import ImageFile

# %%
train_path='C:\\Users\\USERROR\\Downloads\\Dataset\\train'
pred_path='C:\\Users\\USERROR\\Downloads\\Dataset\\predict'

# %%
root = pathlib.Path(train_path)
classes=sorted([j.name.split('/')[-1] for j in root.iterdir()])

# %%
class ConvNet(nn.Module):
    def __init__(self,num_classes=6):
        super(ConvNet,self).__init__()
 
        #((w-f+2P)/s) +1
        
        self.conv1=nn.Conv2d(in_channels=3,out_channels=12,kernel_size=3,stride=1,padding=1)

        self.bn1=nn.BatchNorm2d(num_features=12)

        self.relu1=nn.ReLU()
   
        
        self.pool=nn.MaxPool2d(kernel_size=2)
        
        
        self.conv2=nn.Conv2d(in_channels=12,out_channels=20,kernel_size=3,stride=1,padding=1)
    
        self.relu2=nn.ReLU()
   

        self.conv3=nn.Conv2d(in_channels=20,out_channels=32,kernel_size=3,stride=1,padding=1)
    
        self.bn3=nn.BatchNorm2d(num_features=32)
   
        self.relu3=nn.ReLU()
    
        
        
        self.fc=nn.Linear(in_features=75 * 75 * 32,out_features=num_classes)
        

        
    def forward(self,input):
        output=self.conv1(input)
        output=self.bn1(output)
        output=self.relu1(output)
            
        output=self.pool(output)
            
        output=self.conv2(output)
        output=self.relu2(output)
            
        output=self.conv3(output)
        output=self.bn3(output)
        output=self.relu3(output)
            
            
            
        output=output.view(-1,32*75*75)
            
            
        output=self.fc(output)
            
        return output

# %%
checkpoint=torch.load('best_checkpoint.model')
model=ConvNet(num_classes=6)
model.load_state_dict(checkpoint)
model.eval()
# Out:
# ConvNet(
#   (conv1): Conv2d(3, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn1): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu1): ReLU()
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(12, 20, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu2): ReLU()
#   (conv3): Conv2d(20, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu3): ReLU()
#   (fc): Linear(in_features=180000, out_features=6, bias=True)
# )

# %%
transformer=transforms.Compose([
    transforms.Resize((150,150)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize([0.5,0.5,0.5],
                        [0.5,0.5,0.5])
])

# %%
def prediction(img_path,transformer):
    
    image=Image.open(img_path)
    
    image_tensor=transformer(image).float()
    
    image_tensor=image_tensor.unsqueeze_(0)
    
    if torch.cuda.is_available():
        image_tensor.cuda()
        
    input=Variable(image_tensor)
    
    output=model(input)
    
    index=output.data.numpy().argmax()
    
    pred=classes[index]
    
    return pred

# %%
images_path=glob.glob(pred_path+ '/*.jpg')

# %%
pred_dict={}

for i in images_path:
    pred_dict[i[i.rfind('/')+1:]] =prediction(i, transformer)

# %%
pred_dict
# Out:
# {'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1501).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1502).jpg': 'plastic',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1503).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1504).jpg': 'plastic',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1505).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1506).jpg': 'plastic',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1507).jpg': 'plastic',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1508).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1509).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1510).jpg': 'metal',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1511).jpg': 'plastic',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1512).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1513).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1514).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1515).jpg': 'organic',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1516).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1517).jpg': 'ewaste',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1518).jpg': 'paper',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1519).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1520).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1521).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1522).jpg': 'paper',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1523).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1524).jpg': 'paper',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1525).jpg': 'paper',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1526).jpg': 'organic',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1527).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1528).jpg': 'plastic',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1529).jpg': 'plastic',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1530).jpg': 'plastic',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1531).jpg': 'organic',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1532).jpg': 'plastic',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1533).jpg': 'organic',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1534).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1535).jpg': 'plastic',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1536).jpg': 'organic',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1537).jpg': 'paper',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1538).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1539).jpg': 'ewaste',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1540).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1541).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1542).jpg': 'paper',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1543).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1544).jpg': 'plastic',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1545).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1546).jpg': 'paper',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1547).jpg': 'organic',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1548).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1549).jpg': 'paper',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1550).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1551).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1552).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1553).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1554).jpg': 'metal',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1555).jpg': 'plastic',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1556).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1557).jpg': 'organic',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1558).jpg': 'plastic',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1559).jpg': 'paper',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1560).jpg': 'paper',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1561).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1562).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1563).jpg': 'paper',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1564).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1565).jpg': 'plastic',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1566).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1567).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1568).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1569).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1570).jpg': 'organic',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1571).jpg': 'ewaste',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1572).jpg': 'organic',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1573).jpg': 'ewaste',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1574).jpg': 'paper',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1575).jpg': 'paper',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1576).jpg': 'paper',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1577).jpg': 'plastic',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1578).jpg': 'paper',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1579).jpg': 'plastic',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1580).jpg': 'organic',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1581).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1582).jpg': 'paper',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1583).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1584).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1585).jpg': 'paper',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1586).jpg': 'plastic',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1587).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1588).jpg': 'ewaste',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1589).jpg': 'ewaste',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1590).jpg': 'organic',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1591).jpg': 'paper',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1592).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1593).jpg': 'paper',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1594).jpg': 'organic',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1595).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1596).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1597).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1598).jpg': 'paper',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1599).jpg': 'plastic',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1600).jpg': 'paper',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1601).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1602).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1603).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1604).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1605).jpg': 'paper',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1606).jpg': 'plastic',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1607).jpg': 'paper',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1608).jpg': 'paper',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1609).jpg': 'paper',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1610).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1611).jpg': 'paper',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1612).jpg': 'polythene',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1613).jpg': 'paper',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1614).jpg': 'plastic',
#  'C:\\Users\\USERROR\\Downloads\\Dataset\\predict\\predict (1615).jpg': 'polythene'}
